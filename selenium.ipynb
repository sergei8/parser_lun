# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument('--incognito')
options.add_argument('--headless')
options.add_argument('--silent')
options.add_argument('--log-level=3')

# %%
#driver = webdriver.Chrome("/usr/lib/chromium-browser/chromedriver", chrome_options=options)
driver = webdriver.Chrome(ChromeDriverManager().install(),  chrome_options=options)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 88.0.4324
# [WDM] - Get LATEST driver version for 88.0.4324
# [WDM] - Driver [/Users/sergey/.wdm/drivers/chromedriver/mac64/88.0.4324.96/chromedriver] found in cache
# <ipython-input-20-dd6c2c789e4d>:2: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(),  chrome_options=options)

# %%
url = "https://flatfy.lun.ua/продажа-квартир-киев?page=0"
driver.get(url)
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()

# %%
soup
# Out:
# <html data-react-helmet="lang" lang="ru"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no, minimum-scale=1, maximum-scale=1, viewport-fit=cover" name="viewport"/>
# <link href="https://static.flatfy.com/" rel="preconnect"/>
# <link href="https://browser.sentry-cdn.com/" rel="preconnect"/>
# <link href="https://www.google-analytics.com/" rel="preconnect"/>
# <link as="style" data-chunk="MobileFilterDialogs" href="https://static.flatfy.com/static/spa/media/MobileFilterDialogs.1e4b0537.chunk.css" rel="preload"/>
# <link as="style" data-chunk="MobileFilterDialogs" href="https://static.flatfy.com/static/spa/media/112.e97621f6.chunk.css" rel="preload"/>
# <link as="style" data-chunk="pages-Search" href="https://static.flatfy.com/static/spa/media/pages-Search.30fd8c7f.chunk.css" rel="preload"/>
# <link as="style" data-chunk="pages-Search" href="https://static.flatfy.com/static/spa/media/4.32a6c396.chunk.css" rel="preload"/>
# <link as="style" data-chunk="pages-Search" href="https://static.flatfy.com/static/spa/media/2.7471155c.chunk.css" rel="preload"/>
# <link as="style" data-chunk="main" href="https://static.flatfy.com/static/spa/media/main.f006a5b7.chunk.css" rel="preload"/>
# <link as="style" data-chunk="main" href="https://static.flatfy.com/static/spa/media/183.895b758d.chunk.css" rel="preload"/>
# <link as="script" data-chunk="main" href="https://static.flatfy.com/static/spa/js/runtime-main.89d7fdbd.js" rel="preload"/>
# <link as="script" data-chunk="main" href="https://static.flatfy.com/static/spa/js/chunks/183.0c9b0cc9.chunk.js" rel="preload"/>
# <link as="script" data-chunk="main" href="https://static.flatfy.com/static/spa/js/chunks/main.e6828038.chunk.js" rel="preload"/>
# <link as="script" data-chunk="pages-Search" href="https://static.flatfy.com/static/spa/js/chunks/0.83a92faa.chunk.js" rel="preload"/>
# <link as="script" data-chunk="pages-Search" href="https://static.flatfy.com/static/spa/js/chunks/1.47e32c42.chunk.js" rel="preload"/>
# <link as="script" data-chunk="pages-Search" href="https://static.flatfy.com/static/spa/js/chunks/3.155f10b5.chunk.js" rel="preload"/>
# <link as="script" data-chunk="pages-Search" href="https://static.flatfy.com/static/spa/js/chunks/2.d64b52ee.chunk.js" rel="preload"/>
# <link as="script" data-chunk="pages-Search" href="https://static.flatfy.com/static/spa/js/chunks/4.c081ffcb.chunk.js" rel="preload"/>
# <link as="script" data-chunk="pages-Search" href="https://static.flatfy.com/static/spa/js/chunks/pages-Search.2d4f49a7.chunk.js" rel="preload"/>
# <link as="script" data-chunk="MobileFilterDialogs" href="https://static.flatfy.com/static/spa/js/chunks/112.fac5b112.chunk.js" rel="preload"/>
# <link as="script" data-chunk="MobileFilterDialogs" href="https://static.flatfy.com/static/spa/js/chunks/MobileFilterDialogs.c9274ed0.chunk.js" rel="preload"/>
# <meta content="#ffffff" data-react-helmet="true" name="msapplication-TileColor"/><meta content="https://static.flatfy.com/static/spa/media/msapplication-square144x144logo.da1e7863.png" data-react-helmet="true" name="msapplication-TileImage"/><meta content="https://static.flatfy.com/static/spa/media/msapplication-square70x70logo.1cadbace.png" data-react-helmet="true" name="msapplication-square70x70logo"/><meta content="https://static.flatfy.com/static/spa/media/msapplication-square144x144logo.da1e7863.png" data-react-helmet="true" name="msapplication-square144x144logo"/><meta content="https://static.flatfy.com/static/spa/media/msapplication-square150x150logo.62d7c807.png" data-react-helmet="true" name="msapplication-square150x150logo"/><meta content="https://static.flatfy.com/static/spa/media/msapplication-wide310x150logo.d22151fb.png" data-react-helmet="true" name="msapplication-wide310x150logo"/><meta content="https://static.flatfy.com/static/spa/media/msapplication-square310x310logo.d8680182.png" data-react-helmet="true" name="msapplication-square310x310logo"/><meta content="Flatfy от ЛУН поможет выбрать и купить квартиру в г. Киев на вторичном рынке жилья. Объявления о продаже недвижимости (квартир) Киева на карте с ценой, фото, без посредников. Выбор квартир в любом районе, микрорайоне и на любой улице города. Продажа квартир без посредников или от риелторов." data-react-helmet="true" name="description"/><meta content="noindex, nofollow" data-react-helmet="true" name="robots"/>
# <link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/favicon.c71380f1.ico" rel="icon" sizes="16x16 32x32"/><link data-react-helmet="true" href="data:image/png;base64,..." rel="icon" sizes="16x16"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/favicon@2x.cfb4afe3.png" rel="icon" sizes="32x32"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/apple-touch-icon-57.38928fdf.png" rel="apple-touch-icon"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/apple-touch-icon-57.38928fdf.png" rel="apple-touch-icon" sizes="57x57"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/apple-touch-icon-60.d6ab643a.png" rel="apple-touch-icon" sizes="60x60"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/apple-touch-icon-72.e3f0c55a.png" rel="apple-touch-icon" sizes="72x72"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/apple-touch-icon-76.8b5e7a11.png" rel="apple-touch-icon" sizes="76x76"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/apple-touch-icon-114.6a0aeb43.png" rel="apple-touch-icon" sizes="114x114"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/apple-touch-icon-120.5d9fb221.png" rel="apple-touch-icon" sizes="120x120"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/apple-touch-icon-144.da1e7863.png" rel="apple-touch-icon" sizes="144x144"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/apple-touch-icon-152.2f277362.png" rel="apple-touch-icon" sizes="152x152"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/apple-touch-icon-180.c3b5d49a.png" rel="apple-touch-icon" sizes="180x180"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/android-chrome-128.76255cc3.png" rel="icon" sizes="128x128"/><link data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/android-chrome-192.36594550.png" rel="icon" sizes="192x192"/><link color="#ff9800" data-react-helmet="true" href="https://static.flatfy.com/static/spa/media/safari-pinned-tab.5a353c34.svg" rel="mask-icon"/><link data-react-helmet="true" href="https://flatfy.ua/%D0%BF%D1%80%D0%BE%D0%B4%D0%B0%D0%B6%D0%B0-%D0%BA%D0%B2%D0%B0%D1%80%D1%82%D0%B8%D1%80-%D0%BA%D0%B8%D0%B5%D0%B2?page=0" rel="canonical"/>
# <title>Купить квартиру в Киеве — Продажа квартир Flatfy от ЛУН</title>
# <link data-chunk="main" href="https://static.flatfy.com/static/spa/media/183.895b758d.chunk.css" rel="stylesheet"/>
# <link data-chunk="main" href="https://static.flatfy.com/static/spa/media/main.f006a5b7.chunk.css" rel="stylesheet"/>
# <link data-chunk="pages-Search" href="https://static.flatfy.com/static/spa/media/2.7471155c.chunk.css" rel="stylesheet"/>
# <link data-chunk="pages-Search" href="https://static.flatfy.com/static/spa/media/4.32a6c396.chunk.css" rel="stylesheet"/>
# <link data-chunk="pages-Search" href="https://static.flatfy.com/static/spa/media/pages-Search.30fd8c7f.chunk.css" rel="stylesheet"/>
# <link data-chunk="MobileFilterDialogs" href="https://static.flatfy.com/static/spa/media/112.e97621f6.chunk.css" rel="stylesheet"/>
# <link data-chunk="MobileFilterDialogs" href="https://static.flatfy.com/static/spa/media/MobileFilterDialogs.1e4b0537.chunk.css" rel="stylesheet"/>
# <script async="" src="https://connect.facebook.net/signals/config/955730784557771?v=2.9.33&amp;r=stable"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script>
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# ga('create', 'UA-70971829-37', 'auto');
# </script>
# </head>
# <body class="system-fonts" data-react-helmet="class">
# <noscript>
#         You need to enable JavaScript to run this app.
#       </noscript>
# <div id="root"><div class="page-map-layout page-map-layout--separate-footer"><div class="page-map-layout__header-row"><div class="main-container"><div class="page-map-layout__header"><div class="header header--theme-light"><div class="header__container"><div class="header__start-actions"></div><a class="header__logo header__logo--lun" data-event-action="logo_click" data-event-category="menu" href="/"><div alt="Комфортный поиск квартир" class="header__logo-img header__logo-img--lun" role="img" style='background-image: url("https://static.flatfy.com/static/spa/media/lun-flatfy-black.44656c58.svg");'></div><a class="header__inner-logo-link" href="https://lun.ua" rel="noopener noreferrer" target="_blank"></a></a><div class="header__end-actions"><div class="header__action-holder"></div></div></div><div class="header__menu-block"><div class="header__menu"><div class="header-menu"><button class="header-menu__trigger" type="button"><span class="header-menu__trigger-text">Продажа квартир</span><span class="header-menu__trigger-icon"><svg class="icon" height="10" viewbox="0 0 10 10" width="10"><path d="M5.013 5.8L1.987 3.173c-.223-.194-.608-.25-.839-.03-.23.219-.175.557.048.75L4.61 6.856c.169.146.585.193.808 0l3.35-2.889c.224-.194.336-.535.107-.794-.228-.259-.612-.194-.835 0L5.013 5.801z" fill="currentColor" stroke="currentColor" stroke-width="0.5"></path></svg></span></button><div class="header-menu__dropdown-holder"><div class="header-menu__dropdown"><a class="header-menu__item header-menu__item_selected" data-event-action="section_select" data-event-category="menu" data-event-label="Flat sale" href="/продажа-квартир-киев">Продажа квартир</a><a class="header-menu__item" data-event-action="section_select" data-event-category="menu" data-event-label="Flat rent" href="/аренда-квартир-киев">Aренда квартир</a><a class="header-menu__item" data-event-action="section_select" data-event-category="menu" data-event-label="House sale" href="/продажа-домов-киев">Продажа домов</a><a class="header-menu__item" data-event-action="section_select" data-event-category="menu" data-event-label="House rent" href="/аренда-домов-киев">Aренда домов</a><a class="header-menu__item" data-event-action="section_select" data-event-category="menu" data-event-label="Daily flat rent" href="/посуточная-аренда-киев">Посуточная аренда квартир</a><a class="header-menu__item" data-event-action="section_select" data-event-category="menu" data-event-label="Daily house rent" href="/посуточная-аренда-домов-киев">Посуточная аренда домов</a><a class="header-menu__item" data-event-action="section_select" data-event-category="menu" data-event-label="new_construction" href="https://lun.ua/uk/новобудови-києва">Новостройки<svg class="header-menu__item-icon" height="18" viewbox="30 7 60 18" width="53" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><lineargradient id="buildingsLink_c" x1="82.975%" x2="76.225%" y1="81.437%" y2="107.51%"><stop offset="0%" stop-color="#FFB401" stop-opacity="0"></stop><stop offset="100%" stop-color="#FFB401"></stop></lineargradient><lineargradient id="buildingsLink_d" x1="115.998%" x2="44.044%" y1="41.146%" y2="55.239%"><stop offset="0%" stop-color="#FF7001"></stop><stop offset="100%" stop-color="#FF7001" stop-opacity="0"></stop></lineargradient><lineargradient id="buildingsLink_e" x1="79.681%" x2="54.918%" y1="53.79%" y2="98.533%"><stop offset="0%" stop-color="#FFB301" stop-opacity="0"></stop><stop offset="100%" stop-color="#FFB301"></stop></lineargradient><lineargradient id="buildingsLink_f" x1="83.011%" x2="50%" y1="-24.305%" y2="37.846%"><stop offset="0%" stop-color="#FF7001"></stop><stop offset="100%" stop-color="#FF7001" stop-opacity="0"></stop></lineargradient><path d="M0 0L15.08 0 15.08 14.857 0 14.857z" id="buildingsLink_a"></path><path d="M0 0L15.08 0 15.08 14.857 0 14.857z" id="buildingsLink_b"></path></defs><g fill="none" fill-rule="evenodd"><g><g class="" fill="#161616" fill-rule="nonzero"><path d="M2.32 6.5 ...
# <script type="text/javascript">
#         window.CONFIG = {"enabledExperimentName":"","groupCollapseEnabled":true,"domain":"flatfy.ua","country":"ua","i18nEnabled":true,"defaultLocale":"ru","supportedLocales":["ru","uk"],"timezone":"Europe\u002FKiev","apiURL":"https:\u002F\u002Fapi.flatfy.io","enableInternalAuthApiURL":true,"currency":"UAH","supportedCurrencies":["USD","UAH"],"useDefaultCurrency":false,"currencyPreferSymbol":false,"defaultCityId":1,"googleAuthClientId":"569969836378-4s6hh4o86iuqk50ntrs0sncjud597pgo.apps.googleusercontent.com","recaptchaPublicKey":"6LeODggTAAAAAJWA3vuEtXalWPX05LAbjx8rXKgk","assetsPublicPath":"https:\u002F\u002Fstatic.flatfy.com\u002F","buildingsLinks":{"origin":"https:\u002F\u002Flun.ua","searchWithGeo":"https:\u002F\u002Flun.ua\u002Fuk\u002Fновобудови-києва","cottageLink":"https:\u002F\u002Flun.ua\u002Fuk\u002Fкотеджі\u002Fкиїв","cooperationLink":"https:\u002F\u002Fcosmos.lun.ua\u002Fpages\u002Fboost"},"sentryClientDSN":"https:\u002F\u002F4d696090e71b460486f499dedeb4fa4d@sentry.flatfy.io\u002F2","sentryProjectUrl":"https:\u002F\u002Fsentry.flatfy.io\u002Fflatfy-search\u002Fflatfy","backgroundImage":"ua","useDynamicLogo":false,"nearbyCitiesLinksEnabled":false,"ahrefsVerificationCode":"","citiesWithMap":{"1":"10","2":"10","3":"10","4":"10","5":"10","6":"10","7":"10","9":"10","10":"10","11":"10","16":"10","24":"10","26":"10","31":"10","5591":"10","5593":"10","23825":"10"},"imageStoreTemplate":"https:\u002F\u002Flunappimg.appspot.com\u002Flun-ua\u002F{width}\u002F{height}\u002Fimages-cropped\u002F{image_id}.{extension}","imageStoreFullsizeTemplate":"https:\u002F\u002Fstorage.googleapis.com\u002Flun-ua\u002Fimages-cropped\u002F{image_id}.jpg","geoImageStoreTemplate":"https:\u002F\u002Fstorage.googleapis.com\u002Fhouses-photos\u002Fphotos-resized\u002F700x640\u002F{image_id}.jpg","enableRCPage":false,"enableStreetPage":false,"snapshotTest":false,"version":"0.1-10124-g9273b3b25","realtyMaxTextLength":null,"flairData":"","defaultOpenRealtyTextEnabled":false,"enableExtendedFilters":true,"enableCustomFilters":true,"enableEnhancedGeoField":true,"mapCountry":"ua","mapTilesVersion":"247dd9b0","filterPredefinedValues":{"price":{"UAH":[[null,1000000],[null,1500000],[null,2000000],[null,4000000]],"USD":[[null,50000],[null,70000],[null,100000],[null,200000]]},"fullArea":[[25,null],[45,null],[65,null],[100,null]]},"seoFooterLinks":{},"subscriptions":{"services":["telegram","viber","email"]},"supportedPhotoTypes":{"webp":"image\u002Fwebp","jpg":"image\u002Fjpeg"},"enableLunLogo":true,"isNewBuildingsLogoLun":true,"oldVersionCookieName":"ab_backend_version_v12","oldVersionCookieValue":"A","oldVersionDisableFeedback":true,"oldVersionDomain":"flatfy.lun.ua","disableClosingSeoTextFooter":false,"disableCookiesPopup":true,"realtyGeoAsTitle":true,"enablePremiumDevelopers":true,"facebookLink":"https:\u002F\u002Fwww.facebook.com\u002Fflatfy.ua","messengerLink":"https:\u002F\u002Fm.me\u002Fflatfy.ua","instagramLink":"https:\u002F\u002Fwww.instagram.com\u002Fflatfy.ua","subscriptionsEnableHeaderComposer":false,"analytics":{"enableEnchancedEcommerce":true,"googleAnalytics":"UA-70971829-37","googleTagManager":"","yandexMetrika":"","hotjarSiteId":"","disallowEvents":["page"]},"partnershipLink":"https:\u002F\u002Fpartner.lun.ua","cookiesForSentry":["ab_backend_version_v12"],"advertisement":{"mapping":{"2":["NEW_BUILDING","ADSENSE"],"7":["NEW_BUILDING","ADSENSE"],"11":["NEW_BUILDING","ADSENSE"],"17":["NEW_BUILDING","ADSENSE"]},"adSense":{"enabled":false,"siteId":"4321422396513076"},"newBuildings":{"enabled":true,"enableBanner":false,"enableTopPlace":true,"enableBottomList":true,"korterApiRoot":"","korterApiToken":"","lunApiRoot":"https:\u002F\u002Fnovostroyki-api.lun.ua"}},"eagerImagesLoading":false,"showPlaceAnAdButton":true,"facebookStatisticsLinks":{"ru":{"1":{"1":{"url":"https:\u002F\u002Fwww.facebook.com\u002Fflatfy.ua","label":"Статистика цен на вторичном рынке Киева"}}},"uk":{"1":{"1":{"url":"https:\u002F\u002Fwww.facebook.com\u002Fflatfy.ua","label":"Ста ...
#         window.INITIAL_STATE = {"intl":{"locale":"ru","messages":{"src.components.AdSense.3434877871":"Реклама","src.components.Advertisement.1242107845":"Смотреть","src.components.Seo.1242107845":"Смотреть","src.components.Advertisement.468441986":"Акция","src.components.Advertisement.1260667736":"Новостройка","src.components.Advertisement.2208971002":"Планировка квартиры, {area} в {building}","src.components.Advertisement.196502632":"Уточняется","src.components.Search.SearchResults.196502632":"Уточняется","src.components.Advertisement.3761101386":"{num, plural, one {# комната} few {# комнаты} other {# комнат}}","src.components.RealtyPage.3761101386":"{num, plural, one {# комната} few {# комнаты} other {# комнат}}","src.components.Search.RealtyPreview.3761101386":"{num, plural, one {# комната} few {# комнаты} other {# комнат}}","src.server.subscriptions.email.components.3761101386":"{num, plural, one {# комната} few {# комнаты} other {# комнат}}","src.components.Advertisement.3492503920":"{area} м²","src.components.Search.RealtyPreview.3492503920":"{area} м²","src.server.subscriptions.email.components.3492503920":"{area} м²","src.components.common.1347475195":"Назад","+B6S0w==":"сегодня в","0FPZqA==":"вчера в","src.components.common.3087123780":"{value} {currency}","src.components.common.1905721263":"от {value, number} {currency}","src.components.common.2260557436":"{value} {currency} за м²","L92bxw==":"владелец","gZLcBQ==":"владелец","J5osEQ==":"эксклюзив","xE8nYg==":"актуально","+q6yKQ==":"риелтор","yjBrhg==":"автономное","shth6g==":"индивидуальное","r0lgcA==":"централизованное","W5\u002FlvA==":"АППС","aw2sAA==":"АППС-люкс","7xJFPA==":"БПС","qtFk\u002FQ==":"гостинка","aSLJsg==":"дореволюционный","eeubiQ==":"совмин","iOZdaw==":"серия 134","uvey0Q==":"серия 215","e\u002FYWIA==":"серия 87","PAFUHA==":"серия 96","VcV3uQ==":"серия ЕС","Q4DexQ==":"серия КП","IIHVtw==":"серия КТ","Y5k0BQ==":"серия КС","bzOGIA==":"серия Т","MoMA0g==":"спец. проект","tqoomg==":"сталинка","KAU21w==":"хрущевка","f8rEfg==":"чешский проект","+9qK\u002FQ==":"бельгийский проект","ijDrbA==":"польский дом","oBvFGw==":"польский дом","yOK+sg==":"австрийский люкс","GXbOEQ==":"польский люкс","nink+A==":"малосемейка","+is2Nw==":"блочные","GWUZgg==":"монолитно-каркасные","jnrQ5Q==":"панельные","avqAmQ==":"утепленная панель","4dqWiQ==":"кирпичные","src.components.common.3267667456":"Разместить объявление","src.components.layout.Footer.3267667456":"Разместить объявление","eMm\u002F7Q==":"Разместить объявление","src.components.contacts.613695187":"Мой эксклюзив \u002F я – собственник","src.components.contacts.2089736414":"Объект продан или арендован","src.components.contacts.2630950494":"Неправильная цена","src.components.contacts.1632731489":"Мошенничество","src.components.contacts.4035210090":"Неправильное расположение","src.components.contacts.126134492":"Другое","src.components.FAQ.126134492":"Другое","jc67xg==":"Ссылка на мое объявление","OgHGtg==":"Имя","z\u002Fsjbg==":"E-mail","rSiE+Q==":"Комментарий","1vetUA==":"Мой сайт","BxxMgQ==":"Ваше сообщение отправлено.","HRMvVA==":"Ваш отзыв поможет нам сделать продукт лучше!","src.components.contacts.3383687798":"Спасибо!","src.components.contacts.1247347684":"По техническим причинам сообщение не может быть отправлено.","src.components.contacts.2177257135":"Попробуй позже","src.components.contacts.806123233":"Заполните это поле","src.components.contacts.588387775":"Некорректная ссылка","src.components.contacts.3406710465":"Причина жалобы:","src.components.contacts.1375799028":"Мы напишем Вам на этот email","src.components.contacts.1710866372":"Адрес электронной почты указан не верно :(","src.components.contacts.3525572044":"Пожалуйста, укажите Ваш сайт","src.components.contacts.2927294149":"Некорректная ссылка :(","src.components.contacts.4062214558":"Оставьте Ваши комментарии","src.components.contacts.1359200231":"Отправить","src.components.FAQ.3753593046":"\u003Cp\u003EВ поле “найдено” в карточке объявления мы пиш ...
#       </script>
# <script>window.Sentry=null;</script><script crossorigin="anonymous" integrity="sha384-Nrg+xiw+qRl3grVrxJtWazjeZmUwoSt0FAVsbthlJ5OMpx0G08bqIq3b/v0hPjhB" src="https://browser.sentry-cdn.com/5.15.4/bundle.min.js"></script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[0,1,3,2,4,111,112,116]</script>
# <script async="" data-chunk="main" src="https://static.flatfy.com/static/spa/js/runtime-main.89d7fdbd.js"></script>
# <script async="" data-chunk="main" src="https://static.flatfy.com/static/spa/js/chunks/183.0c9b0cc9.chunk.js"></script>
# <script async="" data-chunk="main" src="https://static.flatfy.com/static/spa/js/chunks/main.e6828038.chunk.js"></script>
# <script async="" data-chunk="pages-Search" src="https://static.flatfy.com/static/spa/js/chunks/0.83a92faa.chunk.js"></script>
# <script async="" data-chunk="pages-Search" src="https://static.flatfy.com/static/spa/js/chunks/1.47e32c42.chunk.js"></script>
# <script async="" data-chunk="pages-Search" src="https://static.flatfy.com/static/spa/js/chunks/3.155f10b5.chunk.js"></script>
# <script async="" data-chunk="pages-Search" src="https://static.flatfy.com/static/spa/js/chunks/2.d64b52ee.chunk.js"></script>
# <script async="" data-chunk="pages-Search" src="https://static.flatfy.com/static/spa/js/chunks/4.c081ffcb.chunk.js"></script>
# <script async="" data-chunk="pages-Search" src="https://static.flatfy.com/static/spa/js/chunks/pages-Search.2d4f49a7.chunk.js"></script>
# <script async="" data-chunk="MobileFilterDialogs" src="https://static.flatfy.com/static/spa/js/chunks/112.fac5b112.chunk.js"></script>
# <script async="" data-chunk="MobileFilterDialogs" src="https://static.flatfy.com/static/spa/js/chunks/MobileFilterDialogs.c9274ed0.chunk.js"></script>
# <script type="text/javascript">
#         !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#         n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#         document,'script','https://connect.facebook.net/en_US/fbevents.js');
#         fbq('init', '955730784557771');
#         fbq('track', 'PageView');
#       </script>
# </body></html>
